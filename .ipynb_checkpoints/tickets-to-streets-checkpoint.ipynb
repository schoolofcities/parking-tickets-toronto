# %% [markdown]
# ## Joining parking ticket data to CentreLines for future mapping

# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import os
import zipfile

# %%
dfs = gpd.read_file('data/centreline/centreline-with-connections.geojson')
dfs["x"] = dfs.centroid.x
dfs["y"] = dfs.centroid.y
dfs = dfs[["CENTRELINE_ID","LINEAR_NAME_FULL","LINEAR_NAME_FULL_LEGAL","LO_NUM_L","HI_NUM_L","LO_NUM_R","HI_NUM_R","PARITY_L","PARITY_R","connecting_streets","x","y"]]
dfs["LINEAR_NAME_FULL"] = dfs["LINEAR_NAME_FULL"].str.upper()
dfs["LINEAR_NAME_FULL_LEGAL"] = dfs["LINEAR_NAME_FULL_LEGAL"].str.upper()
dfs["connecting_streets"] = dfs["connecting_streets"].str.upper()
dfs["city_hall"] = ((abs(dfs["x"] + 79.3839347))**2 + ((abs(dfs["y"] - 43.6534729)))**2)**0.5
# dfs = pd.DataFrame(dfs.loc[(dfs["PARITY_L"] != "N") | (dfs["PARITY_R"] != "N")])
# Out:
# /tmp/ipykernel_16296/4213466026.py:2: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   dfs["x"] = dfs.centroid.x
# /tmp/ipykernel_16296/4213466026.py:3: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   dfs["y"] = dfs.centroid.y

# %%
dfs
# Out:
#        CENTRELINE_ID   LINEAR_NAME_FULL     LINEAR_NAME_FULL_LEGAL  LO_NUM_L  \
# 0             914600        MORRISON ST            MORRISON STREET       NaN
# 1             914601         TWELFTH ST             TWELFTH STREET      66.0
# 2            7862398      THIRTEENTH ST          THIRTEENTH STREET      66.0
# 3             914587  LAKE SHORE BLVD W  LAKE SHORE BOULEVARD WEST       NaN
# 4            6735911  LAKE SHORE BLVD W  LAKE SHORE BOULEVARD WEST    3197.0
# ...              ...                ...                        ...       ...
# 70856       30006687         QUEEN'S DR              QUEEN'S DRIVE     600.0
# 70857         910919        RATHBURN RD              RATHBURN ROAD       NaN
# 70858        8106186        RATHBURN RD              RATHBURN ROAD     367.0
# 70859         910937      THE EAST MALL              THE EAST MALL     596.0
# 70860         910916      THE EAST MALL              THE EAST MALL       NaN
#
#        HI_NUM_L  LO_NUM_R  HI_NUM_R PARITY_L PARITY_R  \
# 0           NaN       NaN       NaN        N        N
# 1          92.0      65.0      89.0        E        O
# 2          96.0      65.0      91.0        E        O
# 3           NaN    3180.0    3180.0        N        E
# 4        3197.0    3190.0    3190.0        O        E
# ...         ...       ...       ...      ...      ...
# 70856     610.0     599.0     613.0        E        O
# 70857       NaN       NaN       NaN        N        N
# 70858     397.0     372.0     400.0        O        E
# 70859     596.0       NaN       NaN        E        N
# 70860       NaN     603.0     603.0        N        O
#
#                                       connecting_streets          x  \
# 0                                TWELFTH ST, ELEVENTH ST -79.509311
# 1                                MORRISON ST, JACKSON RD -79.510109
# 2      MORRISON ST, JACKSON RD, COLONEL SAM SMITH PAR... -79.511105
# 3                            NINETEENTH ST, TWENTIETH ST -79.518596
# 4                          TWENTIETH ST, TWENTY FIRST ST -79.519693
# ...                                                  ...        ...
# 70856              QUEEN'S GREENBELT TRL, GRACEFIELD AVE -79.486042
# 70857             427 C N RATHBURN E RAMP, THE EAST MALL -79.564389
# 70858                        COTTRELLE GT, THE EAST MALL -79.562863
# 70859                     RATHBURN RD, PLANNING BOUNDARY -79.564117
# 70860                         RATHBURN RD, ROBINGLADE DR -79.564488
#
#                y  city_hall
# 0      43.597322   0.137376
# 1      43.597769   0.137923
# 2      43.597538   0.138928
# 3      43.597824   0.145707
# 4      43.597572   0.146817
# ...          ...        ...
# 70856  43.711412   0.117400
# 70857  43.654928   0.180460
# 70858  43.655287   0.178938
# 70859  43.654711   0.180186
# 70860  43.655375   0.180564
#
# [70861 rows x 13 columns]

# %%
# function for input address and return CENTRELINE_ID

def linear_geocode(location2,location3,location4):
        
    # if the address starts with a number:
    try:
        number = int(location2.split(' ', 1)[0])
        street = location2.split(' ', 1)[1]
        dfsf = dfs.loc[dfs['LINEAR_NAME_FULL'] == street]
        dfsf = dfsf.loc[((dfsf["LO_NUM_L"] <= number) & (dfsf["HI_NUM_L"] >= number)) | ((dfsf["LO_NUM_R"] <= number) & (dfsf["HI_NUM_R"] >= number))]
        
        if len(dfsf) == 1:
            centreline = int(dfsf["CENTRELINE_ID"])
            return centreline
            
        elif len(dfsf) > 1:

            maybe = int(dfsf.head(1)["CENTRELINE_ID"])
            
            if number % 2 == 0:
                dfsf = (dfsf.loc[(
                    ((dfsf["PARITY_L"] != "O") & ((dfsf["LO_NUM_L"] <= number) & (dfsf["HI_NUM_L"] >= number))) |
                    ((dfsf["PARITY_R"] != "O") & ((dfsf["LO_NUM_R"] <= number) & (dfsf["HI_NUM_R"] >= number)))
                )])
            if number % 2 == 1:
                dfsf = (dfsf.loc[(
                    ((dfsf["PARITY_L"] != "E") & ((dfsf["LO_NUM_L"] <= number) & (dfsf["HI_NUM_L"] >= number))) |
                    ((dfsf["PARITY_R"] != "E") & ((dfsf["LO_NUM_R"] <= number) & (dfsf["HI_NUM_R"] >= number)))
                )])
                
            if len(dfsf) == 1:
                centreline = int(dfsf["CENTRELINE_ID"])
            elif len(dfsf) > 1:
                dfsf = dfsf[dfsf.city_hall == dfsf.city_hall.min()]
                centreline = int(dfsf.head(1)["CENTRELINE_ID"])
            else:
                centrerline = maybe
            
            return centreline
                
        else:
            
            return 0
        
    # if the address is an intersection
    except:
        
        try:
            dfsf = dfs.loc[dfs['LINEAR_NAME_FULL'] == location2]
            dfsf = dfsf[dfsf['connecting_streets'].str.contains(location4)]

            if len(dfsf) == 1:
                centreline = int(dfsf["CENTRELINE_ID"])
                return centreline

            elif len(dfsf) > 1:

                direction = location3[0]
                if direction == "S":
                    dfsf = dfsf[dfsf.y == dfsf.y.min()]
                    centreline = int(dfsf["CENTRELINE_ID"])
                elif direction == "N":
                    dfsf = dfsf[dfsf.y == dfsf.y.max()]
                    centreline = int(dfsf["CENTRELINE_ID"])
                elif direction == "E":
                    dfsf = dfsf[dfsf.x == dfsf.x.max()]
                    centreline = int(dfsf["CENTRELINE_ID"])
                elif direction == "W":
                    dfsf = dfsf[dfsf.x == dfsf.x.min()]
                    centreline = int(dfsf["CENTRELINE_ID"])
                else:
                    dfsf = dfsf[dfsf.city_hall == dfsf.city_hall.min()]
                    centreline = int(dfsf.head(1)["CENTRELINE_ID"])
                return centreline

            else:
                return -1
        except:
            return -2
    
linear_geocode("170 JOHN ST","","")
linear_geocode("SHAW ST", "S/O", "COLLEGE ST")
linear_geocode("ARMOURY ST","W/O", "CENTRE AVE")
# Out:
# 8087219

# %%
years = [2011]

for year in years:
    dfp = []
    zf = zipfile.ZipFile("data/parking-tickets/parking-tickets-" + str(year) + ".zip")
    csvs = zf.namelist()
    for csv in csvs:
        dfp.append(pd.read_csv(zf.open(csv), engine="python", on_bad_lines='skip'))
        print(csv)
    df = pd.concat(dfp)
    del dfp
    df['CENTRELINE_ID'] = df.apply(lambda x: linear_geocode(x['location2'], x['location3'], x['location4']), axis=1)
    df.to_csv("data/tickets-with-centreline/twc-2015.csv", index=False)
# Out:
# Parking_Tags_Data_2015_1.csv
# Parking_Tags_Data_2015_2.csv
# Parking_Tags_Data_2015_3.csv

# %%
df
# Out:
#        tag_number_masked  date_of_infraction  infraction_code  \
# 0               ***87325            20150101               15
# 1               ***87326            20150101               15
# 2               ***09493            20150101                3
# 3               ***67358            20150101                5
# 4               ***87327            20150101                5
# ...                  ...                 ...              ...
# 668488          ***16116            20151231                3
# 668489          ***03848            20151231               29
# 668490          ***03849            20151231               29
# 668491          ***01046            20151231              347
# 668492          ***66839            20151231                3
#
#                 infraction_description  set_fine_amount  time_of_infraction  \
# 0       PARK-WITHIN 3M OF FIRE HYDRANT              100                 1.0
# 1       PARK-WITHIN 3M OF FIRE HYDRANT              100                 1.0
# 2             PARK ON PRIVATE PROPERTY               30                 2.0
# 3       PARK-SIGNED HWY-PROHIBIT DY/TM               40                 3.0
# 4       PARK-SIGNED HWY-PROHIBIT DY/TM               40                 3.0
# ...                                ...              ...                 ...
# 668488        PARK ON PRIVATE PROPERTY               30              2355.0
# 668489  PARK PROHIBITED TIME NO PERMIT               30              2355.0
# 668490  PARK PROHIBITED TIME NO PERMIT               30              2359.0
# 668491            PARK IN A FIRE ROUTE              250                 NaN
# 668492        PARK ON PRIVATE PROPERTY               30                 NaN
#
#        location1               location2 location3   location4 province
# 0            OPP           11 CENTRE AVE       NaN         NaN       ON
# 1            OPP           11 CENTRE AVE       NaN         NaN       ON
# 2             NR            2425 JANE ST       NaN         NaN       ON
# 3            N/S               DUNDAS SQ       E/O    YONGE ST       ON
# 4            N/S              ARMOURY ST       W/O  CENTRE AVE       ON
# ...          ...                     ...       ...         ...      ...
# 668488       NaN           621 KING ST W       NaN         NaN       ON
# 668489        NR          33 MAITLAND ST       NaN         NaN       ON
# 668490        NR        65 GLOUCESTER ST       NaN         NaN       ON
# 668491       NaN  2743 VICTORIA PARK AVE       NaN         NaN       ON
# 668492       NaN        1340 DANFORTH RD       NaN         NaN       ON
#
# [2168493 rows x 11 columns]

# %%
p,f
# Out:
# (966, 34)

# %%
# Out:
# /tmp/ipykernel_16296/3369371498.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dft['CENTRELINE_ID'] = dft.apply(lambda x: linear_geocode(x['location2'], x['location3'], x['location4']), axis=1)
#     tag_number_masked  date_of_infraction  infraction_code  \
# 0            ***87325            20150101               15
# 1            ***87326            20150101               15
# 2            ***09493            20150101                3
# 3            ***67358            20150101                5
# 4            ***87327            20150101                5
# ..                ...                 ...              ...
# 995          ***53265            20150101               28
# 996          ***68773            20150101               29
# 997          ***08859            20150101                3
# 998          ***46201            20150101               28
# 999          ***46202            20150101               28
#
#              infraction_description  set_fine_amount  time_of_infraction  \
# 0    PARK-WITHIN 3M OF FIRE HYDRANT              100                 1.0
# 1    PARK-WITHIN 3M OF FIRE HYDRANT              100                 1.0
# 2          PARK ON PRIVATE PROPERTY               30                 2.0
# 3    PARK-SIGNED HWY-PROHIBIT DY/TM               40                 3.0
# 4    PARK-SIGNED HWY-PROHIBIT DY/TM               40                 3.0
# ..                              ...              ...                 ...
# 995  PARK-N.YORK 2AM-6AM DEC1-MAR31               40               319.0
# 996  PARK PROHIBITED TIME NO PERMIT               30               319.0
# 997        PARK ON PRIVATE PROPERTY               30               320.0
# 998  PARK-N.YORK 2AM-6AM DEC1-MAR31               40               320.0
# 999  PARK-N.YORK 2AM-6AM DEC1-MAR31               40               320.0
#
#     location1            location2 location3   location4 province  \
# 0         OPP        11 CENTRE AVE       NaN         NaN       ON
# 1         OPP        11 CENTRE AVE       NaN         NaN       ON
# 2          NR         2425 JANE ST       NaN         NaN       ON
# 3         N/S            DUNDAS SQ       E/O    YONGE ST       ON
# 4         N/S           ARMOURY ST       W/O  CENTRE AVE       ON
# ..        ...                  ...       ...         ...      ...
# 995        NR  19 LONDON GREEN CRT       NaN         NaN       ON
# 996        NR     45 BENLAMOND AVE       NaN         NaN       MB
# 997       NaN      2 MEADOWGLEN PL       NaN         NaN       ON
# 998       OPP   40 FOUNTAINHEAD RD       NaN         NaN       ON
# 999        NR   35 FOUNTAINHEAD RD       NaN         NaN       ON
#
#      CENTRELINE_ID
# 0          7792167
# 1          7792167
# 2           443736
# 3          7641766
# 4          8087219
# ..             ...
# 995       30007050
# 996        1140026
# 997       30122285
# 998         439860
# 999         439860
#
# [1000 rows x 12 columns]

# %%
p = 0
f = 0
for index, row in df.head(1000).iterrows():
    cl = linear_geocode(row['location2'],row["location3"],row["location4"])
    if cl <= 0:
        f += 1
        print(row["location2"],row["location3"],row["location4"])
    else:
        p += 1
# Out:
# 10 YUKON PLACE nan nan
# ALBION AVE nan nan
# 14 LONDON GREEN CT nan nan
# 14 LONDON GREE CT nan nan
# 14 LONDON GREEN CT nan nan
# 51 TICHESTER RD nan nan
# 265 MANITOBA DRIVE nan nan
# 10 YUKON PLACE nan nan
# 170 PRINCES BLVD nan nan
# 115 PRINCES BLVD nan nan
# 10 YUKON PLACE nan nan
# 10 YUKON PLACE nan nan
# 10 YUKON PLACE nan nan
# 10 YUKON PLACE nan nan
# 10 YUKON PLACE nan nan
# 10 YUKON PLACE nan nan
# 135 ERSKINE AVE nan nan
# BELVEDERE BLVD W/O WINONA DR
# 10 YUKON PLACE nan nan
# 10 YUKON PLACE nan nan
# 374 WOLVERLEIGH BLVD nan nan
# 10 YUKON PLACE nan nan
# SHAW ST nan COLLEGE ST
# 10 YUKON PLACE nan nan
# 43  MOBERLY AVE nan nan
# 16 TORRESDALE AVE nan nan
# 100 DERRYDOWN RD nan nan
# 99 FAIRMOUNT CRES nan nan
# 66 BURNETT AVE nan nan
# 60 HEMLOCK AVE nan nan
# nan nan nan
# ROANOKE RD nan nan
# 1 CARR ST nan nan
# 1 CARR ST nan nan
