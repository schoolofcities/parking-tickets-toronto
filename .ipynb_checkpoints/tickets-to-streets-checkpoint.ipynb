# %% [markdown]
# ## Joining parking ticket data to CentreLines for future mapping

# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import os
import zipfile

# %%
dfs = gpd.read_file('data/centreline/centreline-with-connections.geojson')
dfs["x"] = dfs.centroid.x
dfs["y"] = dfs.centroid.y
dfs = dfs[["CENTRELINE_ID","LINEAR_NAME_FULL","LINEAR_NAME_FULL_LEGAL","LO_NUM_L","HI_NUM_L","LO_NUM_R","HI_NUM_R","PARITY_L","PARITY_R","connecting_streets","x","y"]]
dfs["LINEAR_NAME_FULL"] = dfs["LINEAR_NAME_FULL"].str.upper()
dfs["LINEAR_NAME_FULL_LEGAL"] = dfs["LINEAR_NAME_FULL_LEGAL"].str.upper()
dfs["connecting_streets"] = dfs["connecting_streets"].str.upper()
# dfs = pd.DataFrame(dfs.loc[(dfs["PARITY_L"] != "N") | (dfs["PARITY_R"] != "N")])
# Out:
# /tmp/ipykernel_16296/3966379043.py:2: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   dfs["x"] = dfs.centroid.x
# /tmp/ipykernel_16296/3966379043.py:3: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   dfs["y"] = dfs.centroid.y

# %%
dfs
# Out:
#        CENTRELINE_ID   LINEAR_NAME_FULL     LINEAR_NAME_FULL_LEGAL  LO_NUM_L  \
# 0             914600        MORRISON ST            MORRISON STREET       NaN
# 1             914601         TWELFTH ST             TWELFTH STREET      66.0
# 2            7862398      THIRTEENTH ST          THIRTEENTH STREET      66.0
# 3             914587  LAKE SHORE BLVD W  LAKE SHORE BOULEVARD WEST       NaN
# 4            6735911  LAKE SHORE BLVD W  LAKE SHORE BOULEVARD WEST    3197.0
# ...              ...                ...                        ...       ...
# 70856       30006687         QUEEN'S DR              QUEEN'S DRIVE     600.0
# 70857         910919        RATHBURN RD              RATHBURN ROAD       NaN
# 70858        8106186        RATHBURN RD              RATHBURN ROAD     367.0
# 70859         910937      THE EAST MALL              THE EAST MALL     596.0
# 70860         910916      THE EAST MALL              THE EAST MALL       NaN
#
#        HI_NUM_L  LO_NUM_R  HI_NUM_R PARITY_L PARITY_R  \
# 0           NaN       NaN       NaN        N        N
# 1          92.0      65.0      89.0        E        O
# 2          96.0      65.0      91.0        E        O
# 3           NaN    3180.0    3180.0        N        E
# 4        3197.0    3190.0    3190.0        O        E
# ...         ...       ...       ...      ...      ...
# 70856     610.0     599.0     613.0        E        O
# 70857       NaN       NaN       NaN        N        N
# 70858     397.0     372.0     400.0        O        E
# 70859     596.0       NaN       NaN        E        N
# 70860       NaN     603.0     603.0        N        O
#
#                                       connecting_streets          x          y
# 0                                TWELFTH ST, ELEVENTH ST -79.509311  43.597322
# 1                                MORRISON ST, JACKSON RD -79.510109  43.597769
# 2      MORRISON ST, JACKSON RD, COLONEL SAM SMITH PAR... -79.511105  43.597538
# 3                            NINETEENTH ST, TWENTIETH ST -79.518596  43.597824
# 4                          TWENTIETH ST, TWENTY FIRST ST -79.519693  43.597572
# ...                                                  ...        ...        ...
# 70856              QUEEN'S GREENBELT TRL, GRACEFIELD AVE -79.486042  43.711412
# 70857             427 C N RATHBURN E RAMP, THE EAST MALL -79.564389  43.654928
# 70858                        COTTRELLE GT, THE EAST MALL -79.562863  43.655287
# 70859                     RATHBURN RD, PLANNING BOUNDARY -79.564117  43.654711
# 70860                         RATHBURN RD, ROBINGLADE DR -79.564488  43.655375
#
# [70861 rows x 12 columns]

# %%
# function for input address and return CENTRELINE_ID

def linear_geocode(location2,location3,location4):
        
    # if the address starts with a number:
    try:
        number = int(location2.split(' ', 1)[0])
        street = location2.split(' ', 1)[1]
        dfsf = dfs.loc[dfs['LINEAR_NAME_FULL'] == street]
        dfsf = dfsf.loc[((dfsf["LO_NUM_L"] <= number) & (dfsf["HI_NUM_L"] >= number)) | ((dfsf["LO_NUM_R"] <= number) & (dfsf["HI_NUM_R"] >= number))]
        
        if len(dfsf) == 1:
            centreline = int(dfsf["CENTRELINE_ID"])
            return centreline
            
        elif len(dfsf) > 1:

            maybe = int(dfsf.head(1)["CENTRELINE_ID"])
            
            if number % 2 == 0:
                dfsf = (dfsf.loc[(
                    ((dfsf["PARITY_L"] != "O") & ((dfsf["LO_NUM_L"] <= number) & (dfsf["HI_NUM_L"] >= number))) |
                    ((dfsf["PARITY_R"] != "O") & ((dfsf["LO_NUM_R"] <= number) & (dfsf["HI_NUM_R"] >= number)))
                )])
            if number % 2 == 1:
                dfsf = (dfsf.loc[(
                    ((dfsf["PARITY_L"] != "E") & ((dfsf["LO_NUM_L"] <= number) & (dfsf["HI_NUM_L"] >= number))) |
                    ((dfsf["PARITY_R"] != "E") & ((dfsf["LO_NUM_R"] <= number) & (dfsf["HI_NUM_R"] >= number)))
                )])
                
            if len(dfsf) == 1:
                centreline = int(dfsf["CENTRELINE_ID"])
            elif len(dfsf) > 1:
                centrerline = int(dfsf.head(1)["CENTRELINE_ID"])
            else:
                centrerline = maybe
            
            return centreline
                
        else:
            
            print("moop")
            return 0
        
    # if the address is an intersection
    except:
        
        try:
            dfsf = dfs.loc[dfs['LINEAR_NAME_FULL'] == location2]
            dfsf = dfsf[dfsf['connecting_streets'].str.contains(location4)]

            if len(dfsf) == 1:
                centreline = int(dfsf["CENTRELINE_ID"])
                return centreline

            elif len(dfsf) > 1:

                direction = location3[0]
                if direction == "S":
                    dfsf = dfsf[dfsf.y == dfsf.y.min()]
                    centreline = int(dfsf["CENTRELINE_ID"])
                elif direction == "N":
                    dfsf = dfsf[dfsf.y == dfsf.y.max()]
                    centreline = int(dfsf["CENTRELINE_ID"])
                elif direction == "E":
                    dfsf = dfsf[dfsf.y == dfsf.x.max()]
                    centreline = int(dfsf["CENTRELINE_ID"])
                elif direction == "W":
                    dfsf = dfsf[dfsf.y == dfsf.x.min()]
                    centreline = int(dfsf["CENTRELINE_ID"])
                else:
                    centrerline = int(dfsf.head(1)["CENTRELINE_ID"])
                return centreline

            else:
                return -1
        except:
            return -2
    
linear_geocode("100 BLOOR ST E","","")
linear_geocode("SHAW ST", "S/O", "COLLEGE ST")
# Out:
#        CENTRELINE_ID LINEAR_NAME_FULL LINEAR_NAME_FULL_LEGAL  LO_NUM_L  \
# 60363       14019718          SHAW ST            SHAW STREET     432.0
#
#        HI_NUM_L  LO_NUM_R  HI_NUM_R PARITY_L PARITY_R  \
# 60363     440.0       NaN       NaN        E        N
#
#                     connecting_streets          x          y
# 60363  COLLEGE ST, LN S COLLEGE E SHAW -79.420188  43.654691
# 14019718

# %%
years = [2020]

for year in years:
    dfs = []
    zf = zipfile.ZipFile("data/parking-tickets/parking-tickets-" + str(year) + ".zip")
    csvs = zf.namelist()
    for csv in csvs:
        dfs.append(pd.read_csv(zf.open(csv), engine="python", on_bad_lines='skip'))
        print(csv)
    df = pd.concat(dfs)
# Out:
# Parking_Tags_Data_2020.000.csv
# Parking_Tags_Data_2020.001.csv
# Parking_Tags_Data_2020.002.csv
# Parking_Tags_Data_2020.003.csv
# Parking_Tags_Data_2020.004.csv
# Parking_Tags_Data_2020.005.csv

# %%
df.head(100)
# Out:
#    tag_number_masked  date_of_infraction  infraction_code  \
# 0           ***60020            20200101                3
# 1           ***46473            20200101               29
# 2           ***46474            20200101               29
# 3           ***46475            20200101               29
# 4           ***46674            20200101               29
# ..               ...                 ...              ...
# 95          ***12447            20200101               29
# 96          ***46720            20200101               29
# 97          ***71465            20200101               29
# 98          ***95016            20200101                5
# 99          ***95017            20200101                5
#
#             infraction_description  set_fine_amount  time_of_infraction  \
# 0         PARK ON PRIVATE PROPERTY               30                 1.0
# 1   PARK PROHIBITED TIME NO PERMIT               30                 2.0
# 2   PARK PROHIBITED TIME NO PERMIT               30                 2.0
# 3   PARK PROHIBITED TIME NO PERMIT               30                 4.0
# 4   PARK PROHIBITED TIME NO PERMIT               30                 4.0
# ..                             ...              ...                 ...
# 95  PARK PROHIBITED TIME NO PERMIT               30                28.0
# 96  PARK PROHIBITED TIME NO PERMIT               30                28.0
# 97  PARK PROHIBITED TIME NO PERMIT               30                28.0
# 98  PARK-SIGNED HWY-PROHIBIT DY/TM               50                29.0
# 99  PARK-SIGNED HWY-PROHIBIT DY/TM               50                29.0
#
#    location1           location2 location3   location4 province
# 0        NaN        4700 JANE ST       NaN         NaN       SK
# 1        OPP   573 CLENDENAN AVE       NaN         NaN       ON
# 2         NR   573 CLENDENAN AVE       NaN         NaN       ON
# 3         NR         21 MARIA ST       NaN         NaN       ON
# 4         NR   164 GLENHOLME AVE       NaN         NaN       ON
# ..       ...                 ...       ...         ...      ...
# 95        NR       515 NAIRN AVE       NaN         NaN       ON
# 96        NR  289 WINDERMERE AVE       NaN         NaN       ON
# 97       E/S         CRAWFORD ST       S/O  SULLY CRES       ON
# 98        NR      40 RICHVIEW RD       NaN         NaN       ON
# 99        NR      40 RICHVIEW RD       NaN         NaN       ON
#
# [100 rows x 11 columns]

# %%
p,f
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_16296/2338893191.py in <module>
# ----> 1 p,f
#
# NameError: name 'p' is not defined

# %%
p = 0
f = 0
for index, row in df.head(1000).iterrows():
    cl = linear_geocode(row['location2'],row["location3"],row["location4"])
    if cl <= 0:
        f += 1
        print(row["location2"],row["location3"],row["location4"])
    else:
        p += 1
# Out:
#        CENTRELINE_ID LINEAR_NAME_FULL LINEAR_NAME_FULL_LEGAL  LO_NUM_L  \
# 60363       14019718          SHAW ST            SHAW STREET     432.0
#
#        HI_NUM_L  LO_NUM_R  HI_NUM_R PARITY_L PARITY_R  \
# 60363     440.0       NaN       NaN        E        N
#
#                     connecting_streets          x          y
# 60363  COLLEGE ST, LN S COLLEGE E SHAW -79.420188  43.654691
#        CENTRELINE_ID LINEAR_NAME_FULL LINEAR_NAME_FULL_LEGAL  LO_NUM_L  \
# 60363       14019718          SHAW ST            SHAW STREET     432.0
#
#        HI_NUM_L  LO_NUM_R  HI_NUM_R PARITY_L PARITY_R  \
# 60363     440.0       NaN       NaN        E        N
#
#                     connecting_streets          x          y
# 60363  COLLEGE ST, LN S COLLEGE E SHAW -79.420188  43.654691
#        CENTRELINE_ID LINEAR_NAME_FULL LINEAR_NAME_FULL_LEGAL  LO_NUM_L  \
# 60363       14019718          SHAW ST            SHAW STREET     432.0
#
#        HI_NUM_L  LO_NUM_R  HI_NUM_R PARITY_L PARITY_R  \
# 60363     440.0       NaN       NaN        E        N
#
#                     connecting_streets          x          y
# 60363  COLLEGE ST, LN S COLLEGE E SHAW -79.420188  43.654691
#        CENTRELINE_ID LINEAR_NAME_FULL LINEAR_NAME_FULL_LEGAL  LO_NUM_L  \
# 60363       14019718          SHAW ST            SHAW STREET     432.0
#
#        HI_NUM_L  LO_NUM_R  HI_NUM_R PARITY_L PARITY_R  \
# 60363     440.0       NaN       NaN        E        N
#
#                     connecting_streets          x          y
# 60363  COLLEGE ST, LN S COLLEGE E SHAW -79.420188  43.654691
#        CENTRELINE_ID LINEAR_NAME_FULL LINEAR_NAME_FULL_LEGAL  LO_NUM_L  \
# 60363       14019718          SHAW ST            SHAW STREET     432.0
#
#        HI_NUM_L  LO_NUM_R  HI_NUM_R PARITY_L PARITY_R  \
# 60363     440.0       NaN       NaN        E        N
#
#                     connecting_streets          x          y
# 60363  COLLEGE ST, LN S COLLEGE E SHAW -79.420188  43.654691
#        CENTRELINE_ID LINEAR_NAME_FULL LINEAR_NAME_FULL_LEGAL  LO_NUM_L  \
# 60363       14019718          SHAW ST            SHAW STREET     432.0
#
#        HI_NUM_L  LO_NUM_R  HI_NUM_R PARITY_L PARITY_R  \
# 60363     440.0       NaN       NaN        E        N
#
#                     connecting_streets          x          y
# 60363  COLLEGE ST, LN S COLLEGE E SHAW -79.420188  43.654691
#        CENTRELINE_ID LINEAR_NAME_FULL LINEAR_NAME_FULL_LEGAL  LO_NUM_L  \
# 60363       14019718          SHAW ST            SHAW STREET     432.0
#
#        HI_NUM_L  LO_NUM_R  HI_NUM_R PARITY_L PARITY_R  \
# 60363     440.0       NaN       NaN        E        N
#
#                     connecting_streets          x          y
# 60363  COLLEGE ST, LN S COLLEGE E SHAW -79.420188  43.654691
#        CENTRELINE_ID LINEAR_NAME_FULL LINEAR_NAME_FULL_LEGAL  LO_NUM_L  \
# 60363       14019718          SHAW ST            SHAW STREET     432.0
#
#        HI_NUM_L  LO_NUM_R  HI_NUM_R PARITY_L PARITY_R  \
# 60363     440.0       NaN       NaN        E        N
#
#                     connecting_streets          x          y
# 60363  COLLEGE ST, LN S COLLEGE E SHAW -79.420188  43.654691
#        CENTRELINE_ID LINEAR_NAME_FULL LINEAR_NAME_FULL_LEGAL  LO_NUM_L  \
# 60363       14019718          SHAW ST            SHAW STREET     432.0
#
#        HI_NUM_L  LO_NUM_R  HI_NUM_R PARITY_L PARITY_R  \
# 60363     440.0       NaN       NaN        E        N
#
#                     connecting_streets          x          y
# 60363  COLLEGE ST, LN S COLLEGE E SHAW -79.420188  43.654691
#        CENTRELINE_ID LINEAR_NAME_FULL LINEAR_NAME_FULL_LEGAL  LO_NUM_L  \
# 60363       14019718          SHAW ST            SHAW STREET     432.0
#
#        HI_NUM_L  LO_NUM_R  HI_NUM_R PARITY_L PARITY_R  \
# 60363     440.0       NaN       NaN        E        N
#
#                     connecting_streets          x          y
# 60363  COLLEGE ST, LN S COLLEGE E SHAW -79.420188  43.654691
#        CENTRELINE_ID LINEAR_NAME_FULL LINEAR_NAME_FULL_LEGAL  LO_NUM_L  \
# 60363       14019718          SHAW ST            SHAW STREET     432.0
#
#        HI_NUM_L  LO_NUM_R  HI_NUM_R PARITY_L PARITY_R  \
# 60363     440.0       NaN       NaN        E        N
#
#                     connecting_streets          x          y
# 60363  COLLEGE ST, LN S COLLEGE E SHAW -79.420188  43.654691
#        CENTRELINE_ID LINEAR_NAME_FULL LINEAR_NAME_FULL_LEGAL  LO_NUM_L  \
# 60363       14019718          SHAW ST            SHAW STREET     432.0
#
#        HI_NUM_L  LO_NUM_R  HI_NUM_R PARITY_L PARITY_R  \
# 60363     440.0       NaN       NaN        E        N
#
#                     connecting_streets          x          y
# 60363  COLLEGE ST, LN S COLLEGE E SHAW -79.420188  43.654691
#        CENTRELINE_ID LINEAR_NAME_FULL LINEAR_NAME_FULL_LEGAL  LO_NUM_L  \
# 60363       14019718          SHAW ST            SHAW STREET     432.0
#
#        HI_NUM_L  LO_NUM_R  HI_NUM_R PARITY_L PARITY_R  \
# 60363     440.0       NaN       NaN        E        N
#
#                     connecting_streets          x          y
# 60363  COLLEGE ST, LN S COLLEGE E SHAW -79.420188  43.654691
#        CENTRELINE_ID LINEAR_NAME_FULL LINEAR_NAME_FULL_LEGAL  LO_NUM_L  \
# 60363       14019718          SHAW ST            SHAW STREET     432.0
#
#        HI_NUM_L  LO_NUM_R  HI_NUM_R PARITY_L PARITY_R  \
# 60363     440.0       NaN       NaN        E        N
#
#                     connecting_streets          x          y
# 60363  COLLEGE ST, LN S COLLEGE E SHAW -79.420188  43.654691
#        CENTRELINE_ID LINEAR_NAME_FULL LINEAR_NAME_FULL_LEGAL  LO_NUM_L  \
# 60363       14019718          SHAW ST            SHAW STREET     432.0
#
#        HI_NUM_L  LO_NUM_R  HI_NUM_R PARITY_L PARITY_R  \
# 60363     440.0       NaN       NaN        E        N
#
#                     connecting_streets          x          y
# 60363  COLLEGE ST, LN S COLLEGE E SHAW -79.420188  43.654691
#        CENTRELINE_ID LINEAR_NAME_FULL LINEAR_NAME_FULL_LEGAL  LO_NUM_L  \
# 60363       14019718          SHAW ST            SHAW STREET     432.0
#
#        HI_NUM_L  LO_NUM_R  HI_NUM_R PARITY_L PARITY_R  \
# 60363     440.0       NaN       NaN        E        N
#
#                     connecting_streets          x          y
# 60363  COLLEGE ST, LN S COLLEGE E SHAW -79.420188  43.654691
#        CENTRELINE_ID LINEAR_NAME_FULL LINEAR_NAME_FULL_LEGAL  LO_NUM_L  \
# 60363       14019718          SHAW ST            SHAW STREET     432.0
#
#        HI_NUM_L  LO_NUM_R  HI_NUM_R PARITY_L PARITY_R  \
# 60363     440.0       NaN       NaN        E        N
#
#                     connecting_streets          x          y
# 60363  COLLEGE ST, LN S COLLEGE E SHAW -79.420188  43.654691
#       CENTRELINE_ID LINEAR_NAME_FULL LINEAR_NAME_FULL_LEGAL  LO_NUM_L  \
# 7263        7994291    CLENDENAN AVE       CLENDENAN AVENUE       NaN
#
#       HI_NUM_L  LO_NUM_R  HI_NUM_R PARITY_L PARITY_R  \
# 7263       NaN     381.0     389.0        N        O
#
#             connecting_streets          x          y
# 7263  JENNINGS AVE, ANNETTE ST -79.472047  43.661755
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_16296/370500733.py in linear_geocode(location2, location3, location4)
#       6     try:
# ----> 7         number = int(location2.split(' ', 1)[0])
#       8         street = location2.split(' ', 1)[1]
#
# ValueError: invalid literal for int() with base 10: 'HARRISON'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_16296/1765648697.py in <module>
#       2 f = 0
#       3 for index, row in df.head(1000).iterrows():
# ----> 4     cl = linear_geocode(row['location2'],row["location3"],row["location4"])
#       5     if cl <= 0:
#       6         f += 1
#
# /tmp/ipykernel_16296/370500733.py in linear_geocode(location2, location3, location4)
#      65             elif direction == "E":
#      66                 dfsf = dfsf[dfsf.y == dfsf.x.max()]
# ---> 67                 centreline = int(dfsf["CENTRELINE_ID"])
#      68             elif direction == "W":
#      69                 dfsf = dfsf[dfsf.y == dfsf.x.min()]
#
# ~/miniconda3/envs/map/lib/python3.8/site-packages/pandas/core/series.py in wrapper(self)
#     183         if len(self) == 1:
#     184             return converter(self.iloc[0])
# --> 185         raise TypeError(f"cannot convert the series to {converter}")
#     186
#     187     wrapper.__name__ = f"__{converter.__name__}__"
#
# TypeError: cannot convert the series to <class 'int'>

# %%
dfs
# Out:
# [       tag_number_masked  date_of_infraction  infraction_code  \
#  0               ***60020            20200101                3
#  1               ***46473            20200101               29
#  2               ***46474            20200101               29
#  3               ***46475            20200101               29
#  4               ***46674            20200101               29
#  ...                  ...                 ...              ...
#  249994          ***27711            20200211                3
#  249995          ***08258            20200211              207
#  249996          ***49838            20200211                3
#  249997          ***21725            20200211                6
#  249998          ***30053            20200211                3
#
#                  infraction_description  set_fine_amount  time_of_infraction  \
#  0             PARK ON PRIVATE PROPERTY               30                 1.0
#  1       PARK PROHIBITED TIME NO PERMIT               30                 2.0
#  2       PARK PROHIBITED TIME NO PERMIT               30                 2.0
#  3       PARK PROHIBITED TIME NO PERMIT               30                 4.0
#  4       PARK PROHIBITED TIME NO PERMIT               30                 4.0
#  ...                                ...              ...                 ...
#  249994        PARK ON PRIVATE PROPERTY               30              1151.0
#  249995  PARK MACHINE-REQD FEE NOT PAID               30              1151.0
#  249996        PARK ON PRIVATE PROPERTY               30              1151.0
#  249997  PARK-SIGNED HWY-EXC PERMT TIME               40              1151.0
#  249998        PARK ON PRIVATE PROPERTY               30              1152.0
#
#         location1            location2 location3 location4 province
#  0            NaN         4700 JANE ST       NaN       NaN       SK
#  1            OPP    573 CLENDENAN AVE       NaN       NaN       ON
#  2             NR    573 CLENDENAN AVE       NaN       NaN       ON
#  3             NR          21 MARIA ST       NaN       NaN       ON
#  4             NR    164 GLENHOLME AVE       NaN       NaN       ON
#  ...          ...                  ...       ...       ...      ...
#  249994       NaN     2075 BAYVIEW AVE       NaN       NaN       ON
#  249995        NR    460 ADELAIDE ST E       NaN       NaN       ON
#  249996        AT    1049 MILITARY TRL       NaN       NaN       ON
#  249997       OPP     26 LADYSMITH AVE       NaN       NaN       ON
#  249998       NaN  1305 LAWRENCE AVE W       NaN       NaN       ON
#
#  [249999 rows x 11 columns],
#         tag_number_masked  date_of_infraction  infraction_code  \
#  0               ***18518            20200211                5
#  1               ***39327            20200211               29
#  2               ***49094            20200211                3
#  3               ***53597            20200211              406
#  4               ***73980            20200211                8
#  ...                  ...                 ...              ...
#  249995          ***63487            20200421                9
#  249996          ***31687            20200421                3
#  249997          ***85803            20200421                3
#  249998          ***97961            20200421               30
#  249999          ***63488            20200421                9
#
#                  infraction_description  set_fine_amount  time_of_infraction  \
#  0       PARK-SIGNED HWY-PROHIBIT DY/TM               50              1152.0
#  1       PARK PROHIBITED TIME NO PERMIT               30              1152.0
#  2             PARK ON PRIVATE PROPERTY               30              1152.0
#  3        PARK-VEH. W/O VALID ONT PLATE               40              1152.0
#  4         STAND VEH.-PROHIBIT TIME/DAY              100              1152.0
#  ...                                ...              ...                 ...
#  249995  STOP-SIGNED HWY-PROHIBIT TM/DY              100              1417.0
#  249996        PARK ON PRIVATE PROPERTY               30              1418.0
#  249997        PARK ON PRIVATE PROPERTY               30              1418.0
#  249998  STOP-(ON/OVER) (SIDEWK/FTPATH)              150              1418.0
#  249999  STOP-SIGNED HWY-PROHIBIT TM/DY              100              1419.0
#
#         location1            location2 location3 location4 province
#  0             NR         55 LISGAR ST       NaN       NaN       ON
#  1             NR         23 WALES AVE       NaN       NaN       ON
#  2             AT        105 KING ST E       NaN       NaN       ON
#  3             NR  524 WELLINGTON ST W       NaN       NaN       ON
#  4             NR        45 BALLIOL ST       NaN       NaN       ON
#  ...          ...                  ...       ...       ...      ...
#  249995       OPP     200 ELIZABETH ST       NaN       NaN       QC
#  249996       NaN        775 KING ST W       NaN       NaN       ON
#  249997        AT     9 APPLEWOOD LANE       NaN       NaN       ON
#  249998        NR     114 GLENDALE AVE       NaN       NaN       ON
#  249999       OPP     200 ELIZABETH ST       NaN       NaN       ON
#
#  [250000 rows x 11 columns],
#         tag_number_masked  date_of_infraction  infraction_code  \
#  0               ***97962            20200421               30
#  1               ***97963            20200421               30
#  2               ***85804            20200421                3
#  3               ***85805            20200421                3
#  4               ***85806            20200421                3
#  ...                  ...                 ...              ...
#  249995          ***34288            20200820              207
#  249996          ***70232            20200820              207
#  249997          ***62955            20200820              207
#  249998          ***07425            20200820              207
#  249999          ***34289            20200820              207
#
#                  infraction_description  set_fine_amount  time_of_infraction  \
#  0       STOP-(ON/OVER) (SIDEWK/FTPATH)              150              1419.0
#  1       STOP-(ON/OVER) (SIDEWK/FTPATH)              150              1420.0
#  2             PARK ON PRIVATE PROPERTY               30              1422.0
#  3             PARK ON PRIVATE PROPERTY               30              1424.0
#  4             PARK ON PRIVATE PROPERTY               30              1428.0
#  ...                                ...              ...                 ...
#  249995  PARK MACHINE-REQD FEE NOT PAID               30              1857.0
#  249996  PARK MACHINE-REQD FEE NOT PAID               30              1858.0
#  249997  PARK MACHINE-REQD FEE NOT PAID               30              1858.0
#  249998  PARK MACHINE-REQD FEE NOT PAID               30              1858.0
#  249999  PARK MACHINE-REQD FEE NOT PAID               30              1858.0
#
#         location1          location2 location3 location4 province
#  0             NR   110 GLENDALE AVE       NaN       NaN       ON
#  1             NR   108 GLENDALE AVE       NaN       NaN       ON
#  2             AT  11 APPLEWOOD LANE       NaN       NaN       ON
#  3             AT  11 APPLEWOOD LANE       NaN       NaN       ON
#  4             AT  11 APPLEWOOD LANE       NaN       NaN       ON
#  ...          ...                ...       ...       ...      ...
#  249995        NR   2890 DUNDAS ST W       NaN       NaN       ON
#  249996        NR      25 SINGER CRT       NaN       NaN       ON
#  249997        NR      186 MUTUAL ST       NaN       NaN       ON
#  249998        NR      3241 YONGE ST       NaN       NaN       NY
#  249999        NR   2890 DUNDAS ST W       NaN       NaN       ON
#
#  [250000 rows x 11 columns],
#         tag_number_masked  date_of_infraction  infraction_code  \
#  0               ***57009            20200820                3
#  1               ***71705            20200820               15
#  2               ***96319            20200820              207
#  3               ***07426            20200820              207
#  4               ***23786            20200820              207
#  ...                  ...                 ...              ...
#  249995          ***24982            20201005               15
#  249996          ***68108            20201005                3
#  249997          ***02455            20201005                3
#  249998          ***44552            20201005                5
#  249999          ***07147            20201005              415
#
#                  infraction_description  set_fine_amount  time_of_infraction  \
#  0             PARK ON PRIVATE PROPERTY               30              1859.0
#  1       PARK-WITHIN 3M OF FIRE HYDRANT              100              1900.0
#  2       PARK MACHINE-REQD FEE NOT PAID               30              1900.0
#  3       PARK MACHINE-REQD FEE NOT PAID               30              1900.0
#  4       PARK MACHINE-REQD FEE NOT PAID               30              1901.0
#  ...                                ...              ...                 ...
#  249995  PARK-WITHIN 3M OF FIRE HYDRANT              100               825.0
#  249996        PARK ON PRIVATE PROPERTY               30               825.0
#  249997        PARK ON PRIVATE PROPERTY               30               826.0
#  249998  PARK-SIGNED HWY-PROHIBIT DY/TM               50               826.0
#  249999  PARK COMMERC LOAD ZONE NOT LDG               40               826.0
#
#         location1           location2 location3 location4 province
#  0            NaN    11 GOLDFINCH CRT       NaN       NaN       ON
#  1             NR        59 HAYDEN ST       NaN       NaN       QC
#  2             NR      627 BLOOR ST W       NaN       NaN       ON
#  3             NR       3243 YONGE ST       NaN       NaN       ON
#  4             NR  294 EGLINTON AVE W       NaN       NaN       ON
#  ...          ...                 ...       ...       ...      ...
#  249995       OPP     9 TEMPERANCE ST       NaN       NaN       ON
#  249996        AT    2580 KIPLING AVE       NaN       NaN       ON
#  249997       NaN  216 DUNCANWOODS DR       NaN       NaN       ON
#  249998        NR     51 BINSWOOD AVE       NaN       NaN       ON
#  249999        NR   136 CUMBERLAND ST       NaN       NaN       ON
#
#  [250000 rows x 11 columns],
#         tag_number_masked  date_of_infraction  infraction_code  \
#  0               ***30108            20201005               29
#  1               ***68109            20201005                3
#  2               ***69402            20201005               29
#  3               ***21316            20201005                5
#  4               ***64093            20201005              207
#  ...                  ...                 ...              ...
#  249995          ***85120            20201120              415
#  249996          ***11209            20201120                3
#  249997          ***07210            20201120              363
#  249998          ***79329            20201120              207
#  249999          ***25790            20201120                3
#
#                  infraction_description  set_fine_amount  time_of_infraction  \
#  0       PARK PROHIBITED TIME NO PERMIT               30               826.0
#  1             PARK ON PRIVATE PROPERTY               30               826.0
#  2       PARK PROHIBITED TIME NO PERMIT               30               826.0
#  3       PARK-SIGNED HWY-PROHIBIT DY/TM               50               827.0
#  4       PARK MACHINE-REQD FEE NOT PAID               30               827.0
#  ...                                ...              ...                 ...
#  249995  PARK COMMERC LOAD ZONE NOT LDG               40              1532.0
#  249996        PARK ON PRIVATE PROPERTY               30              1533.0
#  249997  PARK ONSTRT ACCESSIBLE NO PRMT              450              1533.0
#  249998  PARK MACHINE-REQD FEE NOT PAID               30              1533.0
#  249999        PARK ON PRIVATE PROPERTY               30              1534.0
#
#         location1           location2 location3 location4 province
#  0            OPP    148 GLENDALE AVE       NaN       NaN       ON
#  1             AT    2580 KIPLING AVE       NaN       NaN       ON
#  2             NR  50 ROXBOROUGH ST W       NaN       NaN       ON
#  3             NR  154 LASCELLES BLVD       NaN       NaN       ON
#  4             NR    66 ST PATRICK ST       NaN       NaN       ON
#  ...          ...                 ...       ...       ...      ...
#  249995        NR   124 CUMBERLAND ST       NaN       NaN       ON
#  249996       NaN    4242 DUNDAS S TW       NaN       NaN       ON
#  249997        NR    101 GRENADIER RD       NaN       NaN       ON
#  249998        NR     28 GROSVENOR ST       NaN       NaN       ON
#  249999       NaN    3636 BATHURST ST       NaN       NaN       ON
#
#  [250000 rows x 11 columns],
#         tag_number_masked  date_of_infraction  infraction_code  \
#  0               ***02273            20201120                4
#  1               ***35718            20201120              207
#  2               ***11210            20201120                3
#  3               ***35719            20201120              207
#  4               ***38128            20201120                9
#  ...                  ...                 ...              ...
#  153659          ***42841            20201231              347
#  153660          ***18794            20201231                3
#  153661          ***36469            20201231                3
#  153662          ***38382            20201231                3
#  153663          ***13890            20201231                3
#
#                  infraction_description  set_fine_amount  time_of_infraction  \
#  0           PARK ON MUNICIPAL PROPERTY               30              1534.0
#  1       PARK MACHINE-REQD FEE NOT PAID               30              1534.0
#  2             PARK ON PRIVATE PROPERTY               30              1535.0
#  3       PARK MACHINE-REQD FEE NOT PAID               30              1535.0
#  4       STOP-SIGNED HWY-PROHIBIT TM/DY              100              1535.0
#  ...                                ...              ...                 ...
#  153659            PARK IN A FIRE ROUTE              250              2341.0
#  153660        PARK ON PRIVATE PROPERTY               30              2351.0
#  153661        PARK ON PRIVATE PROPERTY               30                 NaN
#  153662        PARK ON PRIVATE PROPERTY               30                 NaN
#  153663        PARK ON PRIVATE PROPERTY               30                 NaN
#
#         location1           location2 location3 location4 province
#  0            NaN      25 FERRIER AVE       NaN       NaN       ON
#  1             NR  25 TOWN CENTRE CRT       NaN       NaN       ON
#  2            NaN    4242 DUNDAS S TW       NaN       NaN       ON
#  3             NR  25 TOWN CENTRE CRT       NaN       NaN       ON
#  4             NR       35 BALMUTO ST       NaN       NaN       ON
#  ...          ...                 ...       ...       ...      ...
#  153659       NaN      325 BOGERT AVE       NaN       NaN       ON
#  153660        AT         12 YONGE ST       NaN       NaN       ON
#  153661       NaN      40 PANORAMA CT       NaN       NaN       ON
#  153662       NaN     155 REDPATH AVE       NaN       NaN       ON
#  153663       NaN                 NaN       NaN       NaN       ON
#
#  [153664 rows x 11 columns]]
