# %% [markdown]
# ## Joining centrelines to tickets for future mapping
#
# Result is that each parking ticket has a CENTRLINE_ID. This allows for then grouping and summarizing by street

# %%
import pandas as pd
from pandarallel import pandarallel
import geopandas as gpd
import numpy as np
import os
import zipfile
import time

# %%
dfs = gpd.read_file('data/centreline/centreline-with-connections.geojson')
dfs["x"] = dfs.centroid.x
dfs["y"] = dfs.centroid.y
dfs = dfs[["CENTRELINE_ID","LINEAR_NAME_FULL","LINEAR_NAME_FULL_LEGAL","LO_NUM_L","HI_NUM_L","LO_NUM_R","HI_NUM_R","PARITY_L","PARITY_R","connecting_streets","x","y"]]
dfs["LINEAR_NAME_FULL"] = dfs["LINEAR_NAME_FULL"].str.upper()
dfs["LINEAR_NAME_FULL_LEGAL"] = dfs["LINEAR_NAME_FULL_LEGAL"].str.upper()
dfs["connecting_streets"] = dfs["connecting_streets"].str.upper()
dfs["city_hall"] = ((abs(dfs["x"] + 79.3839347))**2 + ((abs(dfs["y"] - 43.6534729)))**2)**0.5
# Out:
# /tmp/ipykernel_42018/4213466026.py:2: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   dfs["x"] = dfs.centroid.x
# /tmp/ipykernel_42018/4213466026.py:3: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   dfs["y"] = dfs.centroid.y

# %%
dfs
# Out:
#        CENTRELINE_ID   LINEAR_NAME_FULL     LINEAR_NAME_FULL_LEGAL  LO_NUM_L  \
# 0             914600        MORRISON ST            MORRISON STREET       NaN
# 1             914601         TWELFTH ST             TWELFTH STREET      66.0
# 2            7862398      THIRTEENTH ST          THIRTEENTH STREET      66.0
# 3             914587  LAKE SHORE BLVD W  LAKE SHORE BOULEVARD WEST       NaN
# 4            6735911  LAKE SHORE BLVD W  LAKE SHORE BOULEVARD WEST    3197.0
# ...              ...                ...                        ...       ...
# 70856       30006687         QUEEN'S DR              QUEEN'S DRIVE     600.0
# 70857         910919        RATHBURN RD              RATHBURN ROAD       NaN
# 70858        8106186        RATHBURN RD              RATHBURN ROAD     367.0
# 70859         910937      THE EAST MALL              THE EAST MALL     596.0
# 70860         910916      THE EAST MALL              THE EAST MALL       NaN
#
#        HI_NUM_L  LO_NUM_R  HI_NUM_R PARITY_L PARITY_R  \
# 0           NaN       NaN       NaN        N        N
# 1          92.0      65.0      89.0        E        O
# 2          96.0      65.0      91.0        E        O
# 3           NaN    3180.0    3180.0        N        E
# 4        3197.0    3190.0    3190.0        O        E
# ...         ...       ...       ...      ...      ...
# 70856     610.0     599.0     613.0        E        O
# 70857       NaN       NaN       NaN        N        N
# 70858     397.0     372.0     400.0        O        E
# 70859     596.0       NaN       NaN        E        N
# 70860       NaN     603.0     603.0        N        O
#
#                                       connecting_streets          x  \
# 0                                TWELFTH ST, ELEVENTH ST -79.509311
# 1                                MORRISON ST, JACKSON RD -79.510109
# 2      MORRISON ST, JACKSON RD, COLONEL SAM SMITH PAR... -79.511105
# 3                            NINETEENTH ST, TWENTIETH ST -79.518596
# 4                          TWENTIETH ST, TWENTY FIRST ST -79.519693
# ...                                                  ...        ...
# 70856              QUEEN'S GREENBELT TRL, GRACEFIELD AVE -79.486042
# 70857             427 C N RATHBURN E RAMP, THE EAST MALL -79.564389
# 70858                        COTTRELLE GT, THE EAST MALL -79.562863
# 70859                     RATHBURN RD, PLANNING BOUNDARY -79.564117
# 70860                         RATHBURN RD, ROBINGLADE DR -79.564488
#
#                y  city_hall
# 0      43.597322   0.137376
# 1      43.597769   0.137923
# 2      43.597538   0.138928
# 3      43.597824   0.145707
# 4      43.597572   0.146817
# ...          ...        ...
# 70856  43.711412   0.117400
# 70857  43.654928   0.180460
# 70858  43.655287   0.178938
# 70859  43.654711   0.180186
# 70860  43.655375   0.180564
#
# [70861 rows x 13 columns]

# %%
# function for input address and return CENTRELINE_ID

def linear_geocode(location2,location3,location4):
        
    # if the address starts with a number:
    try:
        number = int(location2.split(' ', 1)[0])
        street = location2.split(' ', 1)[1]
        dfsf = dfs.loc[dfs['LINEAR_NAME_FULL'] == street]
        dfsf = dfsf.loc[((dfsf["LO_NUM_L"] <= number) & (dfsf["HI_NUM_L"] >= number)) | ((dfsf["LO_NUM_R"] <= number) & (dfsf["HI_NUM_R"] >= number))]
        
        if len(dfsf) == 1:
            centreline = int(dfsf["CENTRELINE_ID"])
            return centreline
            
        elif len(dfsf) > 1:

            maybe = int(dfsf.head(1)["CENTRELINE_ID"])
            
            if number % 2 == 0:
                dfsf = (dfsf.loc[(
                    ((dfsf["PARITY_L"] != "O") & ((dfsf["LO_NUM_L"] <= number) & (dfsf["HI_NUM_L"] >= number))) |
                    ((dfsf["PARITY_R"] != "O") & ((dfsf["LO_NUM_R"] <= number) & (dfsf["HI_NUM_R"] >= number)))
                )])
            if number % 2 == 1:
                dfsf = (dfsf.loc[(
                    ((dfsf["PARITY_L"] != "E") & ((dfsf["LO_NUM_L"] <= number) & (dfsf["HI_NUM_L"] >= number))) |
                    ((dfsf["PARITY_R"] != "E") & ((dfsf["LO_NUM_R"] <= number) & (dfsf["HI_NUM_R"] >= number)))
                )])
                
            if len(dfsf) == 1:
                centreline = int(dfsf["CENTRELINE_ID"])
            elif len(dfsf) > 1:
                dfsf = dfsf[dfsf.city_hall == dfsf.city_hall.min()]
                centreline = int(dfsf.head(1)["CENTRELINE_ID"])
            else:
                centrerline = maybe
            
            return centreline
                
        else:
            
            return 0
        
    # if the address is an intersection
    except:
        
        try:
            dfsf = dfs.loc[dfs['LINEAR_NAME_FULL'] == location2]
            dfsf = dfsf[dfsf['connecting_streets'].str.contains(location4)]

            if len(dfsf) == 1:
                centreline = int(dfsf["CENTRELINE_ID"])
                return centreline

            elif len(dfsf) > 1:

                direction = location3[0]
                if direction == "S":
                    dfsf = dfsf[dfsf.y == dfsf.y.min()]
                    centreline = int(dfsf["CENTRELINE_ID"])
                elif direction == "N":
                    dfsf = dfsf[dfsf.y == dfsf.y.max()]
                    centreline = int(dfsf["CENTRELINE_ID"])
                elif direction == "E":
                    dfsf = dfsf[dfsf.x == dfsf.x.max()]
                    centreline = int(dfsf["CENTRELINE_ID"])
                elif direction == "W":
                    dfsf = dfsf[dfsf.x == dfsf.x.min()]
                    centreline = int(dfsf["CENTRELINE_ID"])
                else:
                    dfsf = dfsf[dfsf.city_hall == dfsf.city_hall.min()]
                    centreline = int(dfsf.head(1)["CENTRELINE_ID"])
                return centreline

            else:
                return -1
        except:
            return -2
    
linear_geocode("170 JOHN ST","","")
linear_geocode("SHAW ST", "S/O", "COLLEGE ST")
linear_geocode("ARMOURY ST","W/O", "CENTRE AVE")
# Out:
# 8087219

# %%
years = [2018,2019,2020]
# [2011,2012,2013,2014,2015,2016,2017,2018,2019,2020]
pandarallel.initialize(progress_bar=True)
for year in years:
    dfp = []
    zf = zipfile.ZipFile("data/parking-tickets/parking-tickets-" + str(year) + ".zip")
    csvs = zf.namelist()
    for csv in csvs:
        dfp.append(pd.read_csv(zf.open(csv), engine="python", on_bad_lines='skip'))
        print(csv)
    df = pd.concat(dfp)
    del dfp
    print(time.time())
    df['CENTRELINE_ID'] = df.parallel_apply(lambda x: linear_geocode(x['location2'], x['location3'], x['location4']), axis=1)
    df.to_csv("data/tickets-with-centreline/twc-" + str(year) + ".gz", index=False)
    print(time.time())
# Out:
# INFO: Pandarallel will run on 2 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.
# Parking_Tags_Data_2012.csv
# 1652913123.4779737
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=1373077), Label(value='0 / 1373077…
# /tmp/ipykernel_42018/1402650733.py:50: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   dfsf = dfsf[dfsf['connecting_streets'].str.contains(location4)]
# /tmp/ipykernel_42018/1402650733.py:50: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   dfsf = dfsf[dfsf['connecting_streets'].str.contains(location4)]
# 1652924765.2511744
# Parking_Tags_Data_2013.csv
# 1652924791.5568597
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=1305788), Label(value='0 / 1305788…
# /tmp/ipykernel_42018/1402650733.py:50: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   dfsf = dfsf[dfsf['connecting_streets'].str.contains(location4)]
# /tmp/ipykernel_42018/1402650733.py:50: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   dfsf = dfsf[dfsf['connecting_streets'].str.contains(location4)]
# 1652935957.758681
# Parking_Tags_Data_2014_2.csv
# Parking_Tags_Data_2014_3.csv
# Parking_Tags_Data_2014_4.csv
# Parking_Tags_Data_2014_1.csv
# 1652935981.7857149
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=1242492), Label(value='0 / 1242492…
# /tmp/ipykernel_42018/1402650733.py:50: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   dfsf = dfsf[dfsf['connecting_streets'].str.contains(location4)]
# /tmp/ipykernel_42018/1402650733.py:50: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   dfsf = dfsf[dfsf['connecting_streets'].str.contains(location4)]
# 1652946191.4745688
# Parking_Tags_Data_2015_1.csv
# Parking_Tags_Data_2015_2.csv
# Parking_Tags_Data_2015_3.csv
# 1652946213.490057
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=1084247), Label(value='0 / 1084247…
# /tmp/ipykernel_42018/1402650733.py:50: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   dfsf = dfsf[dfsf['connecting_streets'].str.contains(location4)]
# /tmp/ipykernel_42018/1402650733.py:50: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   dfsf = dfsf[dfsf['connecting_streets'].str.contains(location4)]
# 1652955191.85461
# Parking_Tags_Data_2016_2.csv
# Parking_Tags_Data_2016_3.csv
# Parking_Tags_Data_2016_4.csv
# Parking_Tags_Data_2016_1.csv
# 1652955214.2674131
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=1127381), Label(value='0 / 1127381…
# /tmp/ipykernel_42018/1402650733.py:50: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   dfsf = dfsf[dfsf['connecting_streets'].str.contains(location4)]
# 1652964627.1002715
# Parking_Tags_Data_2017_1.csv
# Parking_Tags_Data_2017_2.csv
# Parking_Tags_Data_2017_3.csv
# 1652964649.0827582
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=1072113), Label(value='0 / 1072113…
# /tmp/ipykernel_42018/1402650733.py:50: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   dfsf = dfsf[dfsf['connecting_streets'].str.contains(location4)]
# /tmp/ipykernel_42018/1402650733.py:50: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   dfsf = dfsf[dfsf['connecting_streets'].str.contains(location4)]
# 1652974377.4537487
# Parking_Tags_Data_2018_1.csv
# Parking_Tags_Data_2018_2.csv
# Parking_Tags_Data_2018_3.csv
# 1652974399.9951522
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=1022144), Label(value='0 / 1022144…
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_42018/3041815261.py in <module>
#      11     del dfp
#      12     print(time.time())
# ---> 13     df['CENTRELINE_ID'] = df.parallel_apply(lambda x: linear_geocode(x['location2'], x['location3'], x['location4']), axis=1)
#      14     df.to_csv("data/tickets-with-centreline/twc-" + str(year) + ".gz", index=False)
#      15     print(time.time())
#
# ~/miniconda3/envs/map/lib/python3.8/site-packages/pandarallel/core.py in closure(data, user_defined_function, *user_defined_function_args, **user_defined_function_kwargs)
#     305                 )
#     306             ):
# --> 307                 message: Tuple[int, WorkerStatus, Any] = master_workers_queue.get()
#     308                 worker_index, worker_status, payload = message
#     309                 workers_status[worker_index] = worker_status
#
# <string> in get(self, *args, **kwds)
#
# ~/miniconda3/envs/map/lib/python3.8/multiprocessing/managers.py in _callmethod(self, methodname, args, kwds)
#     833
#     834         conn.send((self._id, methodname, args, kwds))
# --> 835         kind, result = conn.recv()
#     836
#     837         if kind == '#RETURN':
#
# ~/miniconda3/envs/map/lib/python3.8/multiprocessing/connection.py in recv(self)
#     248         self._check_closed()
#     249         self._check_readable()
# --> 250         buf = self._recv_bytes()
#     251         return _ForkingPickler.loads(buf.getbuffer())
#     252
#
# ~/miniconda3/envs/map/lib/python3.8/multiprocessing/connection.py in _recv_bytes(self, maxsize)
#     412
#     413     def _recv_bytes(self, maxsize=None):
# --> 414         buf = self._recv(4)
#     415         size, = struct.unpack("!i", buf.getvalue())
#     416         if size == -1:
#
# ~/miniconda3/envs/map/lib/python3.8/multiprocessing/connection.py in _recv(self, size, read)
#     377         remaining = size
#     378         while remaining > 0:
# --> 379             chunk = read(handle, remaining)
#     380             n = len(chunk)
#     381             if n == 0:
#
# KeyboardInterrupt:
# Process ForkPoolWorker-20:
# Traceback (most recent call last):
#   File "/home/jamaps/miniconda3/envs/map/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/jamaps/miniconda3/envs/map/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/jamaps/miniconda3/envs/map/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/jamaps/miniconda3/envs/map/lib/python3.8/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/jamaps/miniconda3/envs/map/lib/python3.8/site-packages/pandarallel/core.py", line 95, in __call__
#     result = self.work_function(
#   File "/home/jamaps/miniconda3/envs/map/lib/python3.8/site-packages/pandarallel/data_types/dataframe.py", line 35, in work
#     return data.apply(
#   File "/home/jamaps/miniconda3/envs/map/lib/python3.8/site-packages/pandas/core/frame.py", line 8740, in apply
#     return op.apply()
#   File "/home/jamaps/miniconda3/envs/map/lib/python3.8/site-packages/pandas/core/apply.py", line 688, in apply
#     return self.apply_standard()
#   File "/home/jamaps/miniconda3/envs/map/lib/python3.8/site-packages/pandas/core/apply.py", line 812, in apply_standard
#     results, res_index = self.apply_series_generator()
#   File "/home/jamaps/miniconda3/envs/map/lib/python3.8/site-packages/pandas/core/apply.py", line 828, in apply_series_generator
#     results[i] = self.f(v)
#   File "/home/jamaps/miniconda3/envs/map/lib/python3.8/site-packages/pandarallel/progress_bars.py", line 201, in closure
#     master_workers_queue.put_nowait((index, WorkerStatus.Running, iteration))
#   File "<string>", line 2, in put_nowait
#   File "/home/jamaps/miniconda3/envs/map/lib/python3.8/multiprocessing/managers.py", line 835, in _callmethod
#     kind, result = conn.recv()
#   File "/home/jamaps/miniconda3/envs/map/lib/python3.8/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#   File "/home/jamaps/miniconda3/envs/map/lib/python3.8/multiprocessing/connection.py", line 414, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/jamaps/miniconda3/envs/map/lib/python3.8/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt

# %%
# 12:57
df
# Out:
#         tag_number_masked  date_of_infraction  infraction_code  \
# 0                ***77243            20110101                8
# 1                ***77244            20110101                8
# 2                ***99464            20110101               29
# 3                ***77245            20110101               15
# 4                ***99465            20110101               29
# ...                   ...                 ...              ...
# 2805487          ***98801            20111231              337
# 2805488          ***20488            20111231                3
# 2805489          ***06162            20111231                5
# 2805490          ***51747            20111231                3
# 2805491          ***77362            20111231               30
#
#                  infraction_description  set_fine_amount  time_of_infraction  \
# 0          STAND VEH HWY PRO TIMES/DAYS               60                 0.0
# 1          STAND VEH HWY PRO TIMES/DAYS               60                 0.0
# 2        PARK PROHIBITED TIME NO PERMIT               30                 0.0
# 3              PARK 3 M OF FIRE HYDRANT              100                 1.0
# 4        PARK PROHIBITED TIME NO PERMIT               30                 1.0
# ...                                 ...              ...                 ...
# 2805487             PARK - ON BOULEVARD               50              2359.0
# 2805488  PARK/LEAVE ON PRIVATE PROPERTY               30                 NaN
# 2805489      PARK HWY PROHIBED TIME/DAY               40                 NaN
# 2805490  PARK/LEAVE ON PRIVATE PROPERTY               30                 NaN
# 2805491  STOP ON/OVER SIDEWALK/FOOTPATH               60                 NaN
#
#         location1              location2 location3    location4 province  \
# 0              NR  60 BRIAN HARRISON WAY       NaN          NaN       ON
# 1              NR  60 BRIAN HARRISON WAY       NaN          NaN       ON
# 2             OPP        241 TORRENS AVE       NaN          NaN       ON
# 3              NR  60 BRIAN HARRISON WAY       NaN          NaN       ON
# 4             OPP        245 TORRENS AVE       NaN          NaN       ON
# ...           ...                    ...       ...          ...      ...
# 2805487       S/S         SHEPPARD AVE E       E/O  NEILSON AVE       ON
# 2805488       NaN           11 BROCK AVE       NaN          NaN       ON
# 2805489       NaN          1392 YONGE ST       NaN          NaN       ON
# 2805490       NaN        35 RICHGROVE DR       NaN          NaN       ON
# 2805491        NR       2993 BATHURST ST       NaN          NaN       ON
#
#          CENTRELINE_ID
# 0           14659972.0
# 1           14659972.0
# 2               1540.0
# 3           14659972.0
# 4               1540.0
# ...                ...
# 2805487            NaN
# 2805488            NaN
# 2805489            NaN
# 2805490            NaN
# 2805491            NaN
#
# [2805492 rows x 12 columns]
